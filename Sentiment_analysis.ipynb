# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import pandas as pd
import re
import  nltk
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.tokenize import word_tokenize as wt
from wordcloud import WordCloud

# %%
Sentiment_analysis = str(input())
# Out:
# nnnnnnnmmmm ggggggggggg hhhhhhhhhhh kkkkkkkkkk llllllllllll rrrrrrrrr dddddddd sssssss hhhhhh nitish

# %%
Sentiment_analysis
# Out:
# 'nnnnnnnmmmm ggggggggggg hhhhhhhhhhh kkkkkkkkkk llllllllllll rrrrrrrrr dddddddd sssssss hhhhhh nitish'

# %%
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
words = wt(Sentiment_analysis)
sentences = wt(Sentiment_analysis)
stop_words = set(stopwords.words('english'))
filtered_words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]

# %%
print(filtered_words)
# Out:
# ['nnnnnnnmmmm', 'ggggggggggg', 'hhhhhhhhhhh', 'kkkkkkkkkk', 'llllllllllll', 'rrrrrrrrr', 'dddddddd', 'sssssss', 'hhhhhh', 'nitish']

# %%
print(stop_words)
# Out:
# {'same', 'where', 'do', 'then', 'won', 'me', 'doesn', 'of', 'down', "haven't", 'it', 'out', 'mustn', 'some', "mustn't", 'on', 'mightn', 'when', 'because', 'just', 'had', 'other', 've', 'their', 'that', 'at', 'such', 'her', 'are', 'ours', 'being', 'will', "you'd", 'his', 'have', 'further', 'each', 'your', 'did', "hasn't", 'am', 'who', 'having', 'a', "you've", "doesn't", 'we', "that'll", 'aren', 'hasn', 'wouldn', 'off', 'there', "weren't", 'an', 'o', 'don', "needn't", 'about', 'was', 'shan', "it's", 'which', 'i', 'if', 'during', "couldn't", 'or', "won't", 'from', 'to', 'under', 'what', 'so', "shan't", 'here', 'isn', 'for', 'you', 'any', 'again', 'were', "isn't", 'only', 'than', 'nor', 'ourselves', "she's", 'into', 'between', 't', 'shouldn', 'she', 'herself', 'how', 'my', 'wasn', 'couldn', 'up', "wasn't", "didn't", 'with', 'should', 'ma', "you'll", 'has', 'him', 'theirs', 'yourselves', 'its', 'himself', 'all', 'before', 'few', "hadn't", 'ain', 'hers', 's', 'own', 'more', 'can', 'been', 'these', "don't", 'myself', 'against', 'in', 'haven', 'by', 'after', 'they', 'm', 'them', 'is', 're', 'those', "you're", 'most', 'be', 'd', 'weren', 'yourself', 'doing', 'too', 'and', 'as', 'until', 'he', 'over', 'no', 'hadn', 'y', "mightn't", 'itself', "should've", 'why', 'll', 'didn', 'needn', 'through', 'below', 'does', 'but', "aren't", 'yours', "shouldn't", 'not', 'the', 'both', 'once', 'very', 'themselves', 'now', 'above', 'while', 'whom', 'our', "wouldn't", 'this'}

# %%
print(sentences)
# Out:
# ['nnnnnnnmmmm', 'ggggggggggg', 'hhhhhhhhhhh', 'kkkkkkkkkk', 'llllllllllll', 'rrrrrrrrr', 'dddddddd', 'sssssss', 'hhhhhh', 'nitish']

# %%
WC = WordCloud(width=4000,height=4000).generate(Sentiment_analysis)
plt.figure(1,figsize=(10,10))
plt.imshow(WC)
